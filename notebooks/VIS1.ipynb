# %% [markdown]
# Step 1: Resize all images at once so PIL doesn't get overwhelmed later

# %%
import os
from PIL import Image

def resize_images_in_folder(folder_path, size=(512, 512)):
    for root, _, files in os.walk(folder_path):
        for file in files:
            if file.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".tiff")):
                img_path = os.path.join(root, file)
                try:
                    with Image.open(img_path) as img:
                        img = img.resize(size, Image.LANCZOS)
                        img.save(img_path)
                        print(f"Resized {img_path}")
                except Exception as e:
                    print(f"Error processing {img_path}: {e}")

if __name__ == "__main__":
    base_folders = [
        "../DATASETS/amalgam/Testing/fire",
        "../DATASETS/amalgam/Testing/nofire",
        "../DATASETS/amalgam/Training and Validation/fire",
        "../DATASETS/amalgam/Training and Validation/nofire"
    ]

    for folder in base_folders:
        resize_images_in_folder(folder, size=(512, 512))
# Out:
# Resized ../DATASETS/amalgam/Testing/fire/36171982712_d1839b35aa_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc180.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52230132421_efbcf13fe2_o.png
# Resized ../DATASETS/amalgam/Testing/fire/36204002431_91b77a7dc5_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50517815722_17ae2240d2_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/9598063779_5a497ff60e_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/41094811384_1382be1721_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/28431967367_37bc44b0c1_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/51284080730_6ab71a3862_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/35531872313_eb8772df72_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50575966873_8cef16dcc6_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/37342469502_36f0ec280c_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc181.jpg
# Resized ../DATASETS/amalgam/Testing/fire/28020330864_d7a2429a7e_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/37342470222_39ab7a0005_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc183.jpg
# Resized ../DATASETS/amalgam/Testing/fire/45922878832_c4755cc402_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/9570772331_0822c9b670_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/26131736898_9e6a8cd68f_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/28811952773_710e9d2d23_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52224743582_c267792d90_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/36296148516_0a2b440e28_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50331586642_e1f77b7c27_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50380846762_05de20fe60_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/28537699003_1a422593ca_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/8469662828_371dbcb70d_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc182.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc169.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52178171048_d3745e41da_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/michael-chacon-wRw3L6hwB2E-unsplash.jpg
# Resized ../DATASETS/amalgam/Testing/fire/51685793514_6fa6a94347_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52530238331_60e6ced567_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc179.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc186.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52871185823_2561dcb25a_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52224745932_9f43b81b98_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/44629829372_5916777e44_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/33352231150_03c54e5e9b_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/51839424127_49f8e61656_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/48690175756_6a3aca7c53_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/29071683967_b1ed99cb89_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc187.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc178.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52465911062_9046fcbb0f_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc185.jpg
# Resized ../DATASETS/amalgam/Testing/fire/matt-palmer-qmFU0516eAk-unsplash.jpg
# Resized ../DATASETS/amalgam/Testing/fire/20960888741_8c4be2c1df_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/36171934502_d220ec0b90_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/8468567451_a6900fa875_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/46580252795_53d18db27b_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50237377031_208e2379f2_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/9600858470_9d349a2271_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc190.jpg
# Resized ../DATASETS/amalgam/Testing/fire/abc184.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52391937615_5103401805_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52530147676_f293f65c1d_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50323624771_c50229c6f9_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/51306907748_6e28024e7d_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/malachi-brooks-QFa3PaR5aos-unsplash.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52390588912_3c6e5f2f67_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/35410488130_9455032ce9_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/48250134737_d2cd909008_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52573687964_c448942429_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/27968020506_5f1a59f2a5_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52290796314_c886e9fd0e_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50380652301_a49c4c245b_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/35015024723_7500837d08_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/28839451467_99ba52a28b_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/9573568070_ec00ce554d_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52293502090_77032c6be0_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52231247312_2442b7ef01_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/30227808988_2cd8f53145_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/29050868872_a81cc9e411_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/28347651877_ce21ed134e_o.png
# Resized ../DATASETS/amalgam/Testing/fire/51785682491_8b035b8bbb_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/9573557452_dfb9664b2f_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/34549858860_4a9183e9af_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50245620368_2f03cf7055_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/matt-palmer-kbTp7dBzHyY-unsplash.jpg
# Resized ../DATASETS/amalgam/Testing/fire/37325108026_bb99689e1f_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/50380847162_24a484981b_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire/52466691809_7b709ba3af_o.jpg
# Resized ../DATASETS/amalgam/Testing/fire
jpg
# Resized ../DATASETS/amalgam/Training and Validation/nofire/nofire_0170.jpg
# Resized ../DATASETS/amalgam/Training and Validation/nofire/nofire_0616.jpg

# %% [markdown]
# Step 2: Use pytorch to train model for recognizing fire/nofire image

# %%
import torch
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from torchvision import models
import torch.nn as nn
import torch.optim as optim
import os
from sklearn.metrics import confusion_matrix, accuracy_score
import numpy as np

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

train_data = ImageFolder("../DATASETS/amalgam/Testing", transform=transform)
val_data = ImageFolder("../DATASETS/amalgam/Training and Validation", transform=transform)

train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32)

model = models.resnet18(pretrained=True)
model.fc = nn.Linear(model.fc.in_features, 2)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    total_loss = 0
    correct = 0
    total = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item() * inputs.size(0)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        total += labels.size(0)

    train_loss = total_loss / total
    train_accuracy = correct / total

    model.eval()
    val_loss = 0
    val_correct = 0
    val_total = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item() * inputs.size(0)
            _, predicted = torch.max(outputs, 1)
            val_correct += (predicted == labels).sum().item()
            val_total += labels.size(0)

    val_loss /= val_total
    val_accuracy = val_correct / val_total

    print(f"Epoch {epoch+1}/{num_epochs} - Train loss: {train_loss:.4f} - Train acc: {train_accuracy:.4f} - Val loss: {val_loss:.4f} - Val acc: {val_accuracy:.4f}")

model.eval()
all_preds = []
all_labels = []
with torch.no_grad():
    for inputs, labels in val_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())

cm = confusion_matrix(all_labels, all_preds)
acc = accuracy_score(all_labels, all_preds)
print("Confusion Matrix:")
print(cm)
print(f"Test Accuracy: {acc:.4f}")
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 46
#      44 outputs = model(inputs)
#      45 loss = criterion(outputs, labels)
# ---> 46 loss.backward()
#      47 optimizer.step()
#      49 total_loss += loss.item() * inputs.size(0)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:626, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     616 if has_torch_function_unary(self):
#     617     return handle_torch_function(
#     618         Tensor.backward,
#     619         (self,),
#    (...)
#     624         inputs=inputs,
#     625     )
# --> 626 torch.autograd.backward(
#     627     self, gradient, retain_graph, create_graph, inputs=inputs
#     628 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/graph.py:823, in _engine_run_backward(t_outputs, *args, **kwargs)
#     821     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822 try:
# --> 823     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824         t_outputs, *args, **kwargs
#     825     )  # Calls into the C++ engine to run the backward pass
#     826 finally:
#     827     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# Save model!

# %%
# Save model
torch.save(model.state_dict(), "resnet18_amalgam.pth")

# %%
import torch
from torchvision import models, transforms
import torch.nn as nn
from PIL import Image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
predict_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

model = models.resnet18()
model.fc = nn.Linear(model.fc.in_features, 2)
model.load_state_dict(torch.load("resnet18_amalgam.pth", map_location=device))
model = model.to(device)
model.eval()

class_names = ['fire', 'nofire']
def predict(image_path):
    image = Image.open(image_path).convert("RGB")
    image = predict_transform(image).unsqueeze(0).to(device)
    with torch.no_grad():
        output = model(image)
        pred = torch.argmax(output, dim=1).item()
    return class_names[pred]

result = predict("../DATASETS/amalgam/Testing/fire/9570772331_0822c9b670_o.jpg")
print("Prediction:", result)
# Out:
# Prediction: fire

# %%
from PIL import Image

def predict(image_path):
    model.eval()
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)

    with torch.no_grad():
        output = model(image)
        pred = torch.argmax(output, dim=1).item()
        return train_data.classes[pred]

predict("../DATASETS_ORIG/forest_fire/Training and Validation/nofire/abc197.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 13
#      10         pred = torch.argmax(output, dim=1).item()
#      11         return train_data.classes[pred]
# ---> 13 predict("../DATASETS_ORIG/forest_fire/Training and Validation/nofire/abc197.jpg")
#
# Cell In[23], line 5, in predict(image_path)
#       3 def predict(image_path):
#       4     model.eval()
# ----> 5     image = Image.open(image_path).convert("RGB")
#       6     image = transform(image).unsqueeze(0).to(device)
#       8     with torch.no_grad():
#
# File /opt/anaconda3/lib/python3.12/site-packages/PIL/Image.py:3431, in open(fp, mode, formats)
#    3428     filename = os.path.realpath(os.fspath(fp))
#    3430 if filename:
# -> 3431     fp = builtins.open(filename, "rb")
#    3432     exclusive_fp = True
#    3433 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/dristiroy/DATASCIFORESTFIRES/DataSciForestFires/DATASETS_ORIG/forest_fire/Training and Validation/nofire/abc197.jpg'
